# %%
import sys
import re
from glob import glob
import os
from itertools import groupby
import pickle
import bs4
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import json
import pickle
import ast
import pandas as pd

# import gensim.downloader as api
# model = api.load('word2vec-google-news-300')

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
class IngredientIndex:
    ''' Class representing an inverted index search tool'''

    def __init__(self):
        
        self.recipes={}
        self.inv_idx={}
        
        with open('RAW_recipes.csv', encoding='utf-8') as f:
                        
            raw_recipes = pd.read_csv(f)
            
            for idx, row in raw_recipes.iterrows():
                
                if type(row['name']) is not str or row['name'] is '':
                    continue
                
                row_id = row['id']
                self.recipes[row_id] = {}
                self.recipes[row_id]['name'] = row['name']
                self.recipes[row_id]['description'] = row['description']
                self.recipes[row_id]['ingredients'] = ast.literal_eval(row['ingredients'])
                self.recipes[row_id]['steps'] = ast.literal_eval(row['steps'])
                self.recipes[row_id]['nutrition'] = ast.literal_eval(row['nutrition'])
                self.recipes[row_id]['tags'] = ast.literal_eval(row['tags'])
                
                self.recipes[row_id]['features'] = set()
                
                for ingredient in self.recipes[row_id]['ingredients']:
                    self.recipes[row_id]['features'].add(lemmatizer.lemmatize(ingredient))
                    
                    single_ingredient_list = ingredient.split()
                    
                    if len(single_ingredient_list) != 1:
                        
                        for single_ingredient in single_ingredient_list:
                            self.recipes[row_id]['features'].add(lemmatizer.lemmatize(single_ingredient))
                
                for ingredient in self.recipes[row_id]['name'].split():
                    self.recipes[row_id]['features'].add(lemmatizer.lemmatize(ingredient))
                
                for ingredient in self.recipes[row_id]['tags']:
                    self.recipes[row_id]['features'].add(lemmatizer.lemmatize(ingredient))
                
                for ingredient in self.recipes[row_id]['features']:
                    if ingredient not in self.inv_idx:
                        self.inv_idx[ingredient] = set()
                    self.inv_idx[ingredient].add(row_id)
                
    def get_id(self, item):
        return self.inv_idx[lemmatizer.lemmatize(item)]
    
    def __getitem__(self, item):
        recipe_ids = self.get_id(item)
        recipe_names = set()
        for recipe in recipe_ids:
            recipe_names.add(self.recipes[recipe]['name'])
        return recipe_names
    
    # Returns set of recipes such that every ingredient in ingredient_list is included in each recipe
    def intersect(self, ingredient_list):
        
        result = -1
        
        for ingredient in ingredient_list:
            if result == -1:
                result = self.get_id(ingredient)
            else:
                result = result.intersection(self.get_id(ingredient))
        
        if result == -1:
            result = set()
        
        return result

    # Returns set of recipes such that at least one ingredient in ingredient_list is included in each recipe
    def union(self, ingredient_list):
        
        result = set()
        
        for ingredient in ingredient_list:
            result = result.union(self.get_id(ingredient))
                
        return result
    
    # Returns set of recipes such that no ingredient in ingredient_list is included in each recipe
    def exclude(self, ingredient_list):
        
        bad_recipes = self.union(ingredient_list)
        
        result = set()
        
        for recipe in self.recipes:
            if recipe not in bad_recipes:
                result.add(recipe)
        
        return result
    
    # Returns set of recipes such that every ingredient in good_ingredient_list is included in each recipe
    # and every ingredient in bad_ingredient_list is not included in each recipe
    def search(self, good_ingredient_list, bad_ingredient_list):
        
        return {self.recipes[recipe_id]['name'] for recipe_id in 
                self.intersect(good_ingredient_list).intersection(self.exclude(bad_ingredient_list))}
    
Pickler = IngredientIndex()

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(Pickler, f)

# %%
with open('model.pkl', 'rb') as f:
    Master = pickle.load(f)

# %%
print(Master.search(['apple', 'sage', 'chicken'], []))
# print(Master.search(['lentils'], []))

# No way to sort by flavor (i.e. salty, sweet)
# No way to filter by allergies or dietary restrictions that encompass more than a single ingredient
# Out:
# {'chicken and sweet potatoes', 'braised celery with apple', 'brining a young turkey', 'butternut squash soup with sage', 'butternut squash  rice and sausage casserole', 'drunken chicken marinade', 'simple stuffing', 'chicken fruit low calorie fat free diet poultry', 'cornbread  sausage  apple    pecan stuffing', 'fresh pumpkin soup by kerry simon', 'apple pie sausage stuffing', 'the best turkey dressing  stuffing', 'sage rubbed pork chops with warm apple slaw', 'northwest harvest gold soup', 'pork chop barley casserole', 'stuffing royale', 'ultimate bbq chicken', 'bacon wrapped pork loin with apples and sage', 'sausage  dried cranberry and apple stuffing', 'sausage and apple stuffing casserole', 'apple   herb stuffing', 'pork chops with calvados', 'autumn harvest stew', 'the best stuffing ever', 'sari fowl   special long cook chicken', 'butternut and apple soup', 'dried cranberry and apple turkey stuffing', 'salt sweet sage roast chicken with roast apple side', 'kelly s holiday apple and sausage stuffing', 'brined and roasted thanksgiving turkey with simple gravy', 'bulgur stuffing with celery  apples and sage', 'thanksgiving panzanella', 'cornbread stuffing with sausage and apples', 'cindy wallace s glazed apple meatloaf', 'apple sage stuffed pork chops', 'chicken with apples and sage', 'a healthy apple and celery soup', 'butternut squash soup with apple and bacon', 'crock pot sausage dressing', 'apple  sage  and berries stuffing', 'chicken with cream  apples and calvados', 'mom s thanksgiving stuffing', 'apple cider chicken', 'roasted turkey breast with apples', 'pan sauteed butternut squash  pears and sage', 'baked chicken on pecan stuffing', 'normandy pork tenderloin', 'crock pot pork  apple and cranberry stew', 'pork chops stuffed with apples and sage', 'jack s apple butter chicken', 'apple and chicken hash', 'chicken thighs with roasted apples and garlic', 'stuffed pork shoulder', 'butternut harvest stew', 'apple sausage stuffing', 'baked pork and apple meatballs  gary rhodes', 'apple and cranberry stuffing', 'creamy pumpkin soup   for weight watching people', 'pork medallions with cranberries and apples', 'sausage stuffing bake', 'autumn pumpkin soup', 'apple sausage stuffing for turkey', 'rye bread stuffing', 'roast turkey   alton brown giada de laurentiis', 'turkey normandy', 'chicken apple bacon burgers', 'homemade chicken and apple sausage', 'apple and sausage stuffing', 'apple chestnut stuffing', 'simply elegant artichoke quiche', 'apple cider brined turkey with savory herb gravy', 'cranberry  sausage  and apple stuffing', 'smoked sausage cassoulet', 'perfect turkey  brined', 'apple festival brunswick stew', 'sage sausage  apple   walnut stuffing dressing', 'roasted pork loin with sage and dried berry stuffing', 'crown roast of pork with savory fruit stuffing', 'paula deen apple stuffed pork loin y all', 'creamy pork and apple stew', 'sage sausage  apple and craisin dressing', 'cider basted turkey with roasted apple gravy', 'ultimate bread turkey stuffing', 'sweet pork with apples and prunes  slow cooker', 'quick pan fried chicken livers with apple  onion and sage', 'the best turkey ever', 'creamy sweet potato soup with baby peas', 'kittencal s sausage and cranberry stuffing', 'marc s chops', 'maple roast turkey', 'wild and brown rice dressing with apples  pecans and cranberries', 'smoked sausage skillet cassoulet', 'rainbow trout   savory cornbread stuffing', 'elegant turkey stuffing', 'bacon   bourbon stuffing  serves 8 10 as a side dish', 'oktoberfest pork roast', 'pork chops with onions  sage and applesauce', 'butternut squash soup with cider cream', 'irish roast pork with cider cream sauce', 'apple and sage stuffing', 'veal chuck chops with onions  cabbage   apples', 'apple glazed roast chicken and rice', 'pork chops with savory apple stuffing'}

# %%
# sweet_dict = {}
# print(nltk.pos_tag(['chicken']))
# for ingredient in temp.inv_idx:
#     try:
#         a = nltk.pos_tag([ingredient])
#         if a[0][1] in {'NN', 'NNS', 'NNP', 'NNPS'}:
#             try:
#                 sweet_dict[ingredient] = model.distance('sweet', ingredient)
#             except KeyError:
#                 pass
#     except IndexError:
#         print(ingredient)


# res = sorted(sweet_dict.items(), key=lambda t: t[1])
# print(res[:50])
# print()
# print(res[-50:])
